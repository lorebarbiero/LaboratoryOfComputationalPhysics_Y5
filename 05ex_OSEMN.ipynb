469911, 0.25470000102449486, 0.9142569843973248, 0.7305297019345125, 0.6796873199205896, 0.9665703628724913, 0.7833897363386183, 0.14233254308467103, 0.683451883415223, 0.779463621832877, 0.7031372359950192, 0.5215319196069814, 0.2098902429383518, 0.6867934926780688, 0.6428666613327351, 0.5547055354898516, 0.2580079509544295, 0.221067639236724, 0.40086396307372174, 0.5629330359841705, 0.07128675775423021, 0.4502177625731121, 0.43771924730426326, 0.5903050913243351, 0.0064964241564809955, 0.7019808507035149, 0.5488915197140455, 0.8956358873463759, 0.9572386581284609, 0.47340720281971826, 0.4129832223845753, 0.019116438012140025, 0.9126662494248816, 0.37621870166353055, 0.31258689535519957, 0.31600056596268045, 0.6813916416066919, 0.5374317758897228, 0.17395155666398288, 0.4530875894935954, 0.3722208909720949, 0.04049146898734679, 0.33412768853726005, 0.46797625426210665, 0.5398702604448021, 0.6100701589534381, 0.6321918879771166, 0.7021466738260358, 0.4970317000101272, 0.09803144289820909, 0.5298850764826987, 0.8470409264848919, 0.008694862059405839, 0.05743053141444754, 0.8417105318253265, 0.10528301345076763, 0.5341587488001931, 0.5045589815865754, 0.9436572874257085, 0.7102422312174779, 0.4643776242500457, 0.4459488932822061, 0.8722310618699921, 0.6202041459281381, 0.9507229191224097, 0.13600583932233734, 0.014731635300332613, 0.6612446110374328, 0.7165348694439485, 0.6763331644252806, 0.8824660231118518, 0.5934454804902194, 0.9995496196547248, 0.5721769167568564, 0.4067463772009342, 0.2763350508211958, 0.16989748599774368, 0.5204110076001707, 0.735556046999761 ...

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
b = npr.rand(5,5)
fname = "/Users/lorenzobarbiero/data/randmat.txt"
np.savetxt(fname, b, delimiter=' ', newline='\n')
print(b)
# Out:
# [[0.62271944 0.70848723 0.42710781 0.27603534 0.33625866]
#  [0.02561197 0.88851297 0.89720575 0.04315197 0.36416624]
#  [0.33254052 0.04126041 0.78352717 0.44457026 0.3735032 ]
#  [0.213978   0.25571378 0.03271705 0.91030225 0.86829696]
#  [0.69494038 0.73018524 0.72860606 0.87484065 0.71638869]]

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
file_name = "/Users/lorenzobarbiero/data/randmat.txt"

# mode can be specified for writing, reading or both
with open(file_name) as f:
    # print-out the whole file
    # print (f.read()) 
    for line in f:
        line2 = ""
        # print line by line
        # print (line)
        # each line is a string, you need to split it yourself
        for c in line.split():
            c = c + ","
            line2 += c
        line = line2
            #print(c) # check the functionalities of the split() method
        print(line)
        
fname = "/Users/lorenzobarbiero/data/csvtry.csv"
np.savetxt(fname,f, delimiter=',', newline='\n')
# Out:
# 6.227194416767009022e-01,7.084872272994906517e-01,4.271078082381134511e-01,2.760353385679299443e-01,3.362586557216449279e-01,
# 2.561196912020247130e-02,8.885129680292244148e-01,8.972057472170569259e-01,4.315196680542643382e-02,3.641662442763372587e-01,
# 3.325405206119279589e-01,4.126041379049216751e-02,7.835271671876610222e-01,4.445702609962625118e-01,3.735031981565852810e-01,
# 2.139780048842060411e-01,2.557137842887798884e-01,3.271704775729422643e-02,9.103022523185129167e-01,8.682969570351962707e-01,
# 6.949403756208586413e-01,7.301852375071468115e-01,7.286060577817790040e-01,8.748406471732451672e-01,7.163886942102107858e-01,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 20>()
#      17         print(line)
#      19 fname = "/Users/lorenzobarbiero/data/csvtry.csv"
# ---> 20 np.savetxt(fname,f, delimiter=',', newline='\n')
#
# File <__array_function__ internals>:5, in savetxt(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/npyio.py:1382, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1380 # Handle 1-dimensional arrays
#    1381 if X.ndim == 0 or X.ndim > 2:
# -> 1382     raise ValueError(
#    1383         "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1384 elif X.ndim == 1:
#    1385     # Common case -- 1d array of numbers
#    1386     if X.dtype.names is None:
#
# ValueError: Expected 1D or 2D array, got 0D array instead

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
file_name = "/Users/lorenzobarbiero/data/credit_card.dat"

from functools import partial
with open(file_name) as f:
    for line in f:
        for chunk in iter(partial(line, 6), '\n'):
            print(repr(chunk), len(chunk))

'''with open(file_name) as f:
    print(chr(int(f.read(4))))
    for line in f:
        #print(line.read(4))
        for c in line.split():
            mask = 0
            a = ""
            while (mask<6):
                a += c
                mask += 1
            num = chr(int(a))'''
        #print (line)'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 4>()
#       4 with open(file_name) as f:
#       5     for line in f:
# ----> 6         for chunk in iter(partial(line, 6), '\n'):
#       7             print(repr(chunk), len(chunk))
#       9 '''with open(file_name) as f:
#      10     print(chr(int(f.read(4))))
#      11     for line in f:
#    (...)
#      18                 mask += 1
#      19             num = chr(int(a))'''
#
# TypeError: the first argument must be callable

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.
